# %%
#type conversion and type casting @input format
#int - string,float,boolean
num = int(input())
print(type(num))
val = float(num)
print(type(val),val)
string_num = str(num)
print(type(string_num),string_num)
print(bool(num))
# Out:
#  0
# <class 'int'>
# <class 'float'> 0.0
# <class 'str'> 0
# False

# %%
# float to - int,string,boolean
val = float(input())
integer_val = int(val)
print(type(integer_val),integer_val)
print(str(val)[:4])
print(bool(val))
# Out:
#  2
# <class 'int'> 2
# 2.0
# True

# %%
# string to - int,float,bool
# string - list,tuple,set
s = input()
#print(int(s))
print(float(s))
print(bool(s))
# Out:
#  10.25
# 10.25
# True

# %%
# string to - int,float,bool
# string - list,tuple,set
s = input()
#print(int(s))
val=float(s)
print(val)
print(int(val))
print(bool(s))
# Out:
#  10
# 10.0
# 10
# True

# %%
# Boolean to - Int,string
booln = bool(input())
print(booln)
# Out:
#  huhudh
# True
