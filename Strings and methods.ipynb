# %%
print('HI')
# Out:
# HI

# %%
print('Hello 134')
# Out:
# Hello 134

# %% [raw]
# #1
# ##2
# ###3

# %%
s ='codegnan'
print(s[2])
# Out:
# d

# %%
s='pavan'
print(s[1:5:1])
print(s[0:5])
# Out:
# avan
# pavan
